# %% [markdown]
# <a href="https://colab.research.google.com/github/HemantBelwal/LLM_Practice/blob/P1/Welcome_To_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
class DummyLLMModel:

  def __init__(self):
    print('LLM created')

  def predict(self, prompt):
    response_list=['My name is Hemant',
                   'Gaur city is sourounded by concrete jungle',
                   'AI stands for Aritifical Intelligence']
    return {'response': random.choice(response_list)}
